# %% [markdown]
# ![A laptop screen with a person typing the word 'seo'](work_laptop.png)

# %% [markdown]
# Imagine working for a digital marketing agency, and the agency is approached by a massive online furniture retailer. They want to test your skills at creating large campaigns for all of their website. You are tasked with creating a prototype set of keywords for search campaigns for their sofas section. The client says that they want you to generate keywords for the following products:
#
# - sofas
# - convertible sofas
# - love seats
# - recliners
# - sofa beds
#
# The client is a low-cost retailer, offering many promotions and discounts. You will need to focus on such keywords. You will also need to move away from luxury keywords and topics, as you are targeting price-sensitive customers. Because they are going to be tight on budget, it would be good to focus on a tightly targeted set of keywords and make sure they are all set to exact and phrase match.
#
# Based on the brief above you will first need to generate a list of words, that together with the products given above would make for good keywords. Here are some examples:
#
# - Products: sofas, recliners
# - Words: buy, prices
#
# The resulting keywords: 'buy sofas', 'sofas buy', 'buy recliners', 'recliners buy', 'prices sofas', 'sofas prices', 'prices recliners', 'recliners prices'.
#
# As a final result, you want to have a DataFrame that looks like this:
#
# <table>
# <thead>
# <tr>
# <th>Campaign</th>
# <th>Ad Group</th>
# <th>Keyword</th>
# <th>Criterion Type</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Campaign1</td>
# <td>AdGroup_1</td>
# <td>keyword 1a</td>
# <td>Exact</td>
# </tr>
# <tr>
# <td>Campaign1</td>
# <td>AdGroup_1</td>
# <td>keyword 1b</td>
# <td>Exact</td>
# </tr>
# <tr>
# <td>Campaign1</td>
# <td>AdGroup_2</td>
# <td>keyword 2a</td>
# <td>Exact</td>
# </tr>
# </tbody>
# </table>

# %%
import pandas as pd

# %%
# Start coding here
# Use as many cells as you need
# List of words to pair with products
words = ["buy", "price", "discount", "promotion", "promo", "shop"]

# print the list of words
print(words)
# Out:
# ['buy', 'price', 'discount', 'promotion', 'promo', 'shop']

# %%
# List of products
products = ["sofas", "convertible sofas", "love seats", "recliners", "sofas beds"]

# Create keywords empty list
keyword_list = []

#Lopp through products
for product in products:
    # Loop through words
    for word in words:
        # Append keywords
            keyword_list.append([product, word + " " + product])
            keyword_list.append([product, product + " " + word])

# Inspect keyword list
print(keyword_list)
# Out:
# [['sofas', 'buy sofas'], ['sofas', 'sofas buy'], ['sofas', 'price sofas'], ['sofas', 'sofas price'], ['sofas', 'discount sofas'], ['sofas', 'sofas discount'], ['sofas', 'promotion sofas'], ['sofas', 'sofas promotion'], ['sofas', 'promo sofas'], ['sofas', 'sofas promo'], ['sofas', 'shop sofas'], ['sofas', 'sofas shop'], ['convertible sofas', 'buy convertible sofas'], ['convertible sofas', 'convertible sofas buy'], ['convertible sofas', 'price convertible sofas'], ['convertible sofas', 'convertible sofas price'], ['convertible sofas', 'discount convertible sofas'], ['convertible sofas', 'convertible sofas discount'], ['convertible sofas', 'promotion convertible sofas'], ['convertible sofas', 'convertible sofas promotion'], ['convertible sofas', 'promo convertible sofas'], ['convertible sofas', 'convertible sofas promo'], ['convertible sofas', 'shop convertible sofas'], ['convertible sofas', 'convertible sofas shop'], ['love seats', 'buy love seats'], ['love seats', 'love seats buy'], ['love seats', 'price love seats'], ['love seats', 'love seats price'], ['love seats', 'discount love seats'], ['love seats', 'love seats discount'], ['love seats', 'promotion love seats'], ['love seats', 'love seats promotion'], ['love seats', 'promo love seats'], ['love seats', 'love seats promo'], ['love seats', 'shop love seats'], ['love seats', 'love seats shop'], ['recliners', 'buy recliners'], ['recliners', 'recliners buy'], ['recliners', 'price recliners'], ['recliners', 'recliners price'], ['recliners', 'discount recliners'], ['recliners', 'recliners discount'], ['recliners', 'promotion recliners'], ['recliners', 'recliners promotion'], ['recliners', 'promo recliners'], ['recliners', 'recliners promo'], ['recliners', 'shop recliners'], ['recliners', 'recliners shop'], ['sofas beds', 'buy sofas beds'], ['sofas beds', 'sofas beds buy'], ['sofas beds', 'price sofas beds'], ['sofas beds', 'sofas beds price'], ['sofas beds', 'discount sofas beds'], ['sofas beds', 'sofas beds discount'], ['sofas beds', 'promotion sofas beds'], ['sofas beds', 'sofas beds promotion'], ['sofas beds', 'promo sofas beds'], ['sofas beds', 'sofas beds promo'], ['sofas beds', 'shop sofas beds'], ['sofas beds', 'sofas beds shop']]

# %%
# Create the keywords Dataframe to explor it
keywords_df = pd.DataFrame(keyword_list, columns=["Ad Group", "Keyword"])

# Print the dataframe to explore it
print(keywords_df)
# Out:
#              Ad Group                      Keyword
# 0               sofas                    buy sofas
# 1               sofas                    sofas buy
# 2               sofas                  price sofas
# 3               sofas                  sofas price
# 4               sofas               discount sofas
# 5               sofas               sofas discount
# 6               sofas              promotion sofas
# 7               sofas              sofas promotion
# 8               sofas                  promo sofas
# 9               sofas                  sofas promo
# 10              sofas                   shop sofas
# 11              sofas                   sofas shop
# 12  convertible sofas        buy convertible sofas
# 13  convertible sofas        convertible sofas buy
# 14  convertible sofas      price convertible sofas
# 15  convertible sofas      convertible sofas price
# 16  convertible sofas   discount convertible sofas
# 17  convertible sofas   convertible sofas discount
# 18  convertible sofas  promotion convertible sofas
# 19  convertible sofas  convertible sofas promotion
# 20  convertible sofas      promo convertible sofas
# 21  convertible sofas      convertible sofas promo
# 22  convertible sofas       shop convertible sofas
# 23  convertible sofas       convertible sofas shop
# 24         love seats               buy love seats
# 25         love seats               love seats buy
# 26         love seats             price love seats
# 27         love seats             love seats price
# 28         love seats          discount love seats
# 29         love seats          love seats discount
# 30         love seats         promotion love seats
# 31         love seats         love seats promotion
# 32         love seats             promo love seats
# 33         love seats             love seats promo
# 34         love seats              shop love seats
# 35         love seats              love seats shop
# 36          recliners                buy recliners
# 37          recliners                recliners buy
# 38          recliners              price recliners
# 39          recliners              recliners price
# 40          recliners           discount recliners
# 41          recliners           recliners discount
# 42          recliners          promotion recliners
# 43          recliners          recliners promotion
# 44          recliners              promo recliners
# 45          recliners              recliners promo
# 46          recliners               shop recliners
# 47          recliners               recliners shop
# 48         sofas beds               buy sofas beds
# 49         sofas beds               sofas beds buy
# 50         sofas beds             price sofas beds
# 51         sofas beds             sofas beds price
# 52         sofas beds          discount sofas beds
# 53         sofas beds          sofas beds discount
# 54         sofas beds         promotion sofas beds
# 55         sofas beds         sofas beds promotion
# 56         sofas beds             promo sofas beds
# 57         sofas beds             sofas beds promo
# 58         sofas beds              shop sofas beds
# 59         sofas beds              sofas beds shop

# %%
# Add a campaign column
keywords_df["Campaign"] = "SEM_Sofas"

# Add a criterion type column 
keywords_df["Criterion Type"] = "Exact"

# Save the final keywords to a CSV file
keywords_df.to_csv("keywords.csv", index= False)
